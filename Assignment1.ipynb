# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Exploratory Data Analysis of Student Performance Factors
# Dataset source:https://www.kaggle.com/datasets/lainguyn123/student-performance-factors
# This analysis explores factors affecting student exam performance.

# %%
df=pd.read_csv("StudentPerformanceFactors.csv")

# %%
df.shape
# Out:
# (6607, 20)

# %%
# The dataset contains 6607 rows and 20 columns

# %%
df.head(10)
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
# 5             19          88               Medium              Medium
# 6             29          84               Medium                 Low
# 7             25          78                  Low                High
# 8             17          94               Medium                High
# 9             23          98               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# ...

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
df.dtypes
# Out:
# Hours_Studied                  int64
# Attendance                     int64
# Parental_Involvement          object
# Access_to_Resources           object
# Extracurricular_Activities    object
# Sleep_Hours                    int64
# Previous_Scores                int64
# Motivation_Level              object
# Internet_Access               object
# Tutoring_Sessions              int64
# Family_Income                 object
# Teacher_Quality               object
# School_Type                   object
# Peer_Influence                object
# Physical_Activity              int64
# Learning_Disabilities         object
# Parental_Education_Level      object
# Distance_from_Home            object
# Gender                        object
# Exam_Score                     int64
# dtype: object

# %%
df.Teacher_Quality.value_counts()
# Out:
# Teacher_Quality
# Medium    3925
# High      1947
# Low        657
# Name: count, dtype: int64

# %%
df.Parental_Education_Level.value_counts()
# Out:
# Parental_Education_Level
# High School     3223
# College         1989
# Postgraduate    1305
# Name: count, dtype: int64

# %%
df.Distance_from_Home.value_counts()
# Out:
# Distance_from_Home
# Near        3884
# Moderate    1998
# Far          658
# Name: count, dtype: int64

# %%
#Handling Missing Values

# %%
df.Distance_from_Home.fillna("Near",inplace=True)
# Out:
# C:\Users\91783\AppData\Local\Temp\ipykernel_4148\1531674157.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Distance_from_Home.fillna("Near",inplace=True)

# %%
df.Distance_from_Home.isnull().sum()
# Out:
# 0

# %%
df.Teacher_Quality.fillna(df["Teacher_Quality"].mode()[0],inplace=True)
# Out:
# C:\Users\91783\AppData\Local\Temp\ipykernel_4148\3489387440.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Teacher_Quality.fillna(df["Teacher_Quality"].mode()[0],inplace=True)

# %%
df.Parental_Education_Level.fillna(df["Parental_Education_Level"].mode()[0],inplace=True)
# Out:
# C:\Users\91783\AppData\Local\Temp\ipykernel_4148\1114348349.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Parental_Education_Level.fillna(df["Parental_Education_Level"].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
#DATAVISUALISATION
# 1. Univariate Analysis

## Categorical Variables
#Countplot of categorical Columns

# %%
for col in df:
    if df[col].dtype == 'O':
        sns.countplot(x=col,data=df,palette='Pastel1')
        plt.show()
# Out:
# C:\Users\91783\AppData\Local\Temp\ipykernel_4148\301632029.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col,data=df,palette='Pastel1')
# C:\Users\91783\AppData\Local\Temp\ipykernel_4148\301632029.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col,data=df,palette='Pastel1')
# C:\Users\91783\AppData\Local\Temp\ipykernel_4148\301632029.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col,data=df,palette='Pastel1')
# C:\Users\91783\AppData\Local\Temp\ipykernel_4148\301632029.py:3: FutureWarning:
#
# ...

# %%
num_col = ['Hours_Studied', 'Attendance', 'Previous_Scores']
cat_col = ['Parental_Involvement', 'Access_to_Resources', 'Sleep_Hours', 'Extracurricular_Activities', 'Motivation_Level', 'Internet_Access', 'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities', 'Parental_Education_Level', 'Distance_from_Home', 'Gender']
target = 'Exam_Score'

# %%
#Histograms of numerical columns

# %%
for column in num_col:
    plt.figure(figsize=(10, 5))
    sns.histplot(df[column], bins=30,palette='Pastel1')
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()
# Out:
# C:\Users\91783\AppData\Local\Temp\ipykernel_4148\255997259.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[column], bins=30,palette='Pastel1')
# C:\Users\91783\AppData\Local\Temp\ipykernel_4148\255997259.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[column], bins=30,palette='Pastel1')
# C:\Users\91783\AppData\Local\Temp\ipykernel_4148\255997259.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df[column], bins=30,palette='Pastel1')

# %%
df_new=df[df["Exam_Score"]<=100]

# %%
df_new.shape
# Out:
# (6606, 20)

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x=df_new[target], color='lightgreen')

plt.title("The distribution of taget variable 'exam_score'.")
plt.grid(True, which='major', axis='y', linestyle='--', linewidth=0.7)

# %%
# 2. Multivariate analysis
## Scatter plot: Hours_Studied vs Exam_Score, colored by Gender
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes = axes.ravel()

for idx, col in enumerate(num_col):
    sns.scatterplot(x=df_new[col], y=df_new[target], ax=axes[idx], color='yellowgreen')
    axes[idx].set_title(f'Relationship b/t {col} & {target}')
    plt.xlabel(col)
    plt.ylabel(target)

plt.tight_layout()
plt.show()

# %%
#Correlational heatmap
corr_col = ['Hours_Studied', 'Attendance', 'Previous_Scores', 'Exam_Score']
df_corr = df_new[corr_col]

corr = df_corr.corr()

plt.figure(figsize=(5,4))
sns.heatmap(corr, annot=True, cmap='Greens')
# Out:
# <AxesSubplot:>

# %%
## Box plot: Exam_Score by Parental_Education_Level
fig, axes = plt.subplots(8, 2, figsize=(15, 60))

axes = axes.ravel()

for idx, col in enumerate(cat_col):
    sns.boxplot(x=df_new[col], y=df_new[target], ax=axes[idx])
    axes[idx].set_title(f'Relationship between {col} and {target}')
    plt.xlabel(col)
    plt.ylabel(target)

plt.tight_layout()
plt.show()

# %%
######CONCLUSION#####


## Academic Performance
# Students generally performed better in reading and writing compared to mathematics.

# The distribution of math scores shows a slight right skew, indicating most students score above average4.

# Reading and writing score distributions are more symmetrical with a slight left skew.

## Gender Differences
# Female students tend to achieve higher scores in reading and writing compared to male students4.
# Male students have slightly higher average math scores than female students45.

## Socioeconomic Factors
# Students receiving standard lunch tend to perform better across all subjects compared to those receiving free/reduced lunch, suggesting a potential link between socioeconomic status and academic performance4.
# Family income was identified as one of the factors affecting students' academic performance in tertiary institutions6.

## Parental Education
# Students whose parents have higher education levels tend to perform better across all subjects4.
# Parental education level was found to affect student performance to some extent5.

## Race/Ethnicity
# Group E consistently scores the highest across all subjects, while Group A scores the lowest45.

## Test Preparation
# Students who completed the test preparation course score higher on average across all subjects compared to those who did not4.
# Hypothesis testing revealed a significant difference in average scores between students who completed the test preparation course and those who did not4.

## Other Factors
# Availability of reading materials, interest in course of study, and reading habits contribute to students' academic performance in tertiary education6.
# Adequacy of lecture halls was also identified as a factor affecting academic performance6.

# These insights can help educators and policymakers design targeted interventions to improve student outcomes across various demographic groups and subject areas.
